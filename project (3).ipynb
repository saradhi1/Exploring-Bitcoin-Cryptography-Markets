# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\cse\Desktop\AI\coinmarketcap_06122017.csv")

# %%
df
# Out:
#       Unnamed: 0  24h_volume_usd  available_supply                 id  \
# 0              0    9.007640e+09      1.672352e+07            bitcoin
# 1              1    1.551330e+09      9.616537e+07           ethereum
# 2              2    1.111350e+09      1.684044e+07       bitcoin-cash
# 3              3    2.936090e+09      2.779530e+09               iota
# 4              4    2.315050e+08      3.873915e+10             ripple
# 5              5    2.289430e+08      7.736420e+06               dash
# 6              6    4.093420e+08      5.415391e+07           litecoin
# 7              7    1.384070e+08      1.669097e+07       bitcoin-gold
# 8              8    5.498600e+08      1.544296e+07             monero
# 9              9    6.164750e+07      2.592707e+10            cardano
# 10            10    4.020670e+08      9.812566e+07   ethereum-classic
# 11            11    3.172850e+07      9.000000e+09                nem
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  24h_volume_usd  available_supply            id  last_updated  \
# 0           0    9.007640e+09      1.672352e+07       bitcoin    1512549554
# 1           1    1.551330e+09      9.616537e+07      ethereum    1512549553
# 2           2    1.111350e+09      1.684044e+07  bitcoin-cash    1512549578
# 3           3    2.936090e+09      2.779530e+09          iota    1512549571
# 4           4    2.315050e+08      3.873915e+10        ripple    1512549541
#
#    market_cap_usd    max_supply          name  percent_change_1h  \
# 0    2.130493e+11  2.100000e+07       Bitcoin               0.12
# 1    4.352945e+10           NaN      Ethereum              -0.18
# 2    2.529585e+10  2.100000e+07  Bitcoin Cash               1.65
# 3    1.475225e+10  2.779530e+09          IOTA              -2.38
# 4    9.365343e+09  1.000000e+11        Ripple               0.56
#
#    percent_change_24h  percent_change_7d  price_btc     price_usd  rank  \
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0            False
# 24h_volume_usd         True
# available_supply       True
# id                    False
# last_updated          False
# market_cap_usd         True
# max_supply             True
# name                  False
# percent_change_1h      True
# percent_change_24h     True
# percent_change_7d      True
# price_btc             False
# price_usd             False
# rank                  False
# symbol                False
# total_supply           True
# dtype: bool

# %%
df.drop(["id","symbol","rank","24h_volume_usd","available_supply","last_updated","market_cap_usd","max_supply","price_btc","price_usd"],axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0               name  percent_change_1h  percent_change_24h  \
# 0              0            Bitcoin               0.12                7.33
# 1              1           Ethereum              -0.18               -3.93
# 2              2       Bitcoin Cash               1.65               -5.51
# 3              3               IOTA              -2.38               83.35
# 4              4             Ripple               0.56               -3.70
# 5              5               Dash               1.22               -3.31
# 6              6           Litecoin              -0.17                0.80
# 7              7       Bitcoin Gold              -0.86               -8.65
# 8              8             Monero              -2.00               25.65
# 9              9            Cardano              -0.28               -5.80
# 10            10   Ethereum Classic              -0.20               -3.47
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0            False
# name                  False
# percent_change_1h      True
# percent_change_24h     True
# percent_change_7d      True
# total_supply           True
# dtype: bool

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.isnull().any()
# Out:
# Unnamed: 0            False
# name                  False
# percent_change_1h     False
# percent_change_24h    False
# percent_change_7d     False
# total_supply          False
# dtype: bool

# %%
df
# Out:
#       Unnamed: 0               name  percent_change_1h  percent_change_24h  \
# 0              0            Bitcoin           0.120000            7.330000
# 1              1           Ethereum          -0.180000           -3.930000
# 2              2       Bitcoin Cash           1.650000           -5.510000
# 3              3               IOTA          -2.380000           83.350000
# 4              4             Ripple           0.560000           -3.700000
# 5              5               Dash           1.220000           -3.310000
# 6              6           Litecoin          -0.170000            0.800000
# 7              7       Bitcoin Gold          -0.860000           -8.650000
# 8              8             Monero          -2.000000           25.650000
# 9              9            Cardano          -0.280000           -5.800000
# 10            10   Ethereum Classic          -0.200000           -3.470000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0          name  percent_change_1h  percent_change_24h  \
# 0           0       Bitcoin               0.12                7.33
# 1           1      Ethereum              -0.18               -3.93
# 2           2  Bitcoin Cash               1.65               -5.51
# 3           3          IOTA              -2.38               83.35
# 4           4        Ripple               0.56               -3.70
#
#    percent_change_7d  total_supply
# 0              17.45  1.672352e+07
# 1              -7.33  9.616537e+07
# 2              -4.75  1.684044e+07
# 3             255.82  2.779530e+09
# 4             -14.79  9.999309e+10

# %%
x=df.iloc[:,2:5].values

# %%
x
# Out:
# array([[  0.12      ,   7.33      ,  17.45      ],
#        [ -0.18      ,  -3.93      ,  -7.33      ],
#        [  1.65      ,  -5.51      ,  -4.75      ],
#        ...,
#        [ -0.37      , -37.39      , -27.69      ],
#        [  1.05243519,   4.39      , -22.84      ],
#        [  1.05243519,   8.65567717,  -6.83      ]])

# %%
y=df.iloc[:,5].values

# %%
y
# Out:
# array([1.6723525e+07, 9.6165368e+07, 1.6840438e+07, ..., 2.5023800e+06,
#        1.0200000e+10, 1.0000000e+07])

# %%
x
# Out:
# array([[  0.12      ,   7.33      ,  17.45      ],
#        [ -0.18      ,  -3.93      ,  -7.33      ],
#        [  1.65      ,  -5.51      ,  -4.75      ],
#        ...,
#        [ -0.37      , -37.39      , -27.69      ],
#        [  1.05243519,   4.39      , -22.84      ],
#        [  1.05243519,   8.65567717,  -6.83      ]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[  0.54,   6.31,  15.17],
#        [  0.54,   2.57,  11.09],
#        [  0.52, -12.36, -22.62],
#        ...,
#        [-37.55, -63.75, -52.59],
#        [  0.46,   0.78,  29.91],
#        [ -1.53,   0.28,   1.48]])

# %%
y_train
# Out:
# array([7.8496447e+11, 7.8496447e+11, 5.3033136e+08, ..., 7.8496447e+11,
#        3.5347000e+04, 7.9570760e+08])

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr=LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=mlr.predict(x_test)

# %%
x_test
# Out:
# array([[ 1.25000000e+00,  4.70000000e+00, -1.63000000e+01],
#        [ 5.40000000e-01,  6.31000000e+00,  1.70700000e+01],
#        [ 1.71200000e+01,  2.50000000e-01,  9.39200000e+01],
#        [ 1.72000000e+00, -1.61400000e+01,  3.41700000e+01],
#        [ 5.10000000e-01,  4.36100000e+01,  1.12200000e+01],
#        [-5.70000000e-01,  1.15200000e+01,  2.10900000e+01],
#        [ 1.30000000e+00, -8.19000000e+00, -2.45000000e+00],
#        [ 5.40000000e-01,  8.65567717e+00,  1.11390000e+02],
#        [ 7.00000000e-01,  5.47000000e+00,  3.58100000e+01],
#        [ 3.24000000e+00, -4.75700000e+01, -7.17000000e+01],
#        [ 5.40000000e-01,  6.31000000e+00,  1.86700000e+01],
#        [ 3.70000000e+00,  3.52000000e+00, -1.86100000e+01],
#        [ 1.22300000e+01,  7.84000000e+00, -5.50000000e+00],
#        [ 4.90000000e+00, -1.31600000e+01,  9.10000000e-01],
#        [ 3.10000000e-01,  5.34000000e+00, -1.05000000e+01],
#        [ 8.61000000e+00,  7.85800000e+01,  1.85760000e+02],
# ...

# %%
y_test
# Out:
# array([1.62963900e+06, 2.45324000e+06, 7.84964470e+11, 1.84194753e+08,
#        7.84964470e+11, 1.62940620e+07, 2.05218256e+08, 7.84964470e+11,
#        1.34813000e+07, 9.84620900e+06, 7.84964470e+11, 3.00000000e+09,
#        3.35655612e+10, 1.00000000e+10, 1.00000000e+08, 2.14748365e+09,
#        6.00000000e+08, 8.03519300e+06, 4.42204000e+07, 6.04491100e+06,
#        1.14780564e+08, 7.73642000e+06, 8.89996870e+07, 4.00000000e+08,
#        1.00000000e+08, 1.00000000e+11, 2.96216000e+05, 1.96150190e+07,
#        7.00112590e+07, 1.70622047e+08, 4.18392000e+07, 1.30271020e+08,
#        5.29352682e+08, 8.33370000e+07, 7.84964470e+11, 1.99089100e+06,
#        7.84964470e+11, 2.12680920e+07, 8.62186852e+08, 2.70000000e+07,
#        1.69598616e+08, 5.00000000e+08, 2.31925310e+07, 7.84964470e+11,
#        1.20731000e+06, 1.00000000e+09, 5.94105100e+08, 4.20658300e+06,
#        2.48536697e+08, 1.21351980e+07, 9.74155440e+07, 2.49194000e+07,
# ...

# %%
y_pred
# Out:
# array([7.82711192e+10, 7.69491551e+10, 7.20498177e+10, 7.23361779e+10,
#        8.35085989e+10, 7.76460652e+10, 7.54363159e+10, 7.28182698e+10,
#        7.59067206e+10, 7.21081513e+10, 7.68723830e+10, 7.81549900e+10,
#        7.81543867e+10, 7.43968797e+10, 7.81114232e+10, 8.09262086e+10,
#        7.80916416e+10, 7.79643113e+10, 7.48125307e+10, 7.73778146e+10,
#        7.77095057e+10, 7.56305599e+10, 7.44330157e+10, 7.66464990e+10,
#        7.66479331e+10, 7.59465798e+10, 7.51866826e+10, 7.55412682e+10,
#        7.32380782e+10, 7.37738914e+10, 7.21787094e+10, 7.52599805e+10,
#        7.53617399e+10, 7.31060323e+10, 7.70521998e+10, 7.67460386e+10,
#        7.72272116e+10, 9.99515886e+10, 7.66733636e+10, 7.16444032e+10,
#        5.50894135e+10, 7.75500952e+10, 7.69755143e+10, 7.73846132e+10,
#        7.66583400e+10, 7.54397213e+10, 8.58752999e+10, 7.57886035e+10,
#        7.52605859e+10, 7.39736140e+10, 7.46972731e+10, 7.99059668e+10,
# ...

# %%
x_train.shape
# Out:
# (1060, 3)

# %%
pred=mlr.predict([[0.12,7.33,17.45]])

# %%
pred
# Out:
# array([7.71074697e+10])

# %%
y_pred=mlr.predict(x_test)

# %%
y_pred
# Out:
# array([7.82711192e+10, 7.69491551e+10, 7.20498177e+10, 7.23361779e+10,
#        8.35085989e+10, 7.76460652e+10, 7.54363159e+10, 7.28182698e+10,
#        7.59067206e+10, 7.21081513e+10, 7.68723830e+10, 7.81549900e+10,
#        7.81543867e+10, 7.43968797e+10, 7.81114232e+10, 8.09262086e+10,
#        7.80916416e+10, 7.79643113e+10, 7.48125307e+10, 7.73778146e+10,
#        7.77095057e+10, 7.56305599e+10, 7.44330157e+10, 7.66464990e+10,
#        7.66479331e+10, 7.59465798e+10, 7.51866826e+10, 7.55412682e+10,
#        7.32380782e+10, 7.37738914e+10, 7.21787094e+10, 7.52599805e+10,
#        7.53617399e+10, 7.31060323e+10, 7.70521998e+10, 7.67460386e+10,
#        7.72272116e+10, 9.99515886e+10, 7.66733636e+10, 7.16444032e+10,
#        5.50894135e+10, 7.75500952e+10, 7.69755143e+10, 7.73846132e+10,
#        7.66583400e+10, 7.54397213e+10, 8.58752999e+10, 7.57886035e+10,
#        7.52605859e+10, 7.39736140e+10, 7.46972731e+10, 7.99059668e+10,
# ...

# %%
from sklearn.metrics import r2_score,accuracy_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.003911388118474912

# %%
df.corr()
# Out:
#                     Unnamed: 0  percent_change_1h  percent_change_24h  \
# Unnamed: 0            1.000000           0.012846            0.011241
# percent_change_1h     0.012846           1.000000            0.201672
# percent_change_24h    0.011241           0.201672            1.000000
# percent_change_7d    -0.066647           0.082560            0.393188
# total_supply          0.012576          -0.001256           -0.001341
#
#                     percent_change_7d  total_supply
# Unnamed: 0                  -0.066647      0.012576
# percent_change_1h            0.082560     -0.001256
# percent_change_24h           0.393188     -0.001341
# percent_change_7d            1.000000     -0.002741
# total_supply                -0.002741      1.000000
